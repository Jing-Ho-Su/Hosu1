# %%
# 변수는 어떻게 만들까???

a = 1
b = "python"
c = [1, 2, 3]

# 현재 a, b, c 의 각 변수에 오른쪽 요소들이 할당되어 있다고 생각하면 편하다

# %%
# 변수명 규치
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.

a1 = 1
t1 = 1
typescript = 1
type_script = 1
type-script = 1 # 언더스코어가 아니라서 안된다
typeScript = 1
TypeScript = 1
# Out:
#   Cell In[7], line 8
#     type-script = 1 # 언더스코어가 아니라서 안된다
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# 변수명 규치
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.
# 2. 숫자로 시작할 수 없다.

t1 = 1
1 = t
# Out:
#   Cell In[8], line 6
#     1 = t
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# 변수명 규치
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.
# 2. 숫자로 시작할 수 없다.
# 3. 예약어는 사용할 수 없다.

print = 1
len
False
True
and
if
from
import

print
# Out:
#   Cell In[10], line 10
#     and
#     ^
# SyntaxError: invalid syntax

# %%
# 변수명 규치
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.
# 2. 숫자로 시작할 수 없다.
# 3. 예약어는 사용할 수 없다.
# 4. 대소문자를 구분한다.

Abc = 1
abc = 2

print(Abc)
print(abc)
# Out:
# 1
# 2

# %%
# 변수에 순서대로 들어간다


#(a, b) = ("python", "Life")
a, b = "python", "Life"

print(a)
print(b)
# Out:
# python
# Life

# %%
[a,b]=["python","life"]

print(a)
print(b)
# Out:
# python
# life
